# %% [markdown]
# # Data exploration
#
# ---
#
# Group name: Gruppe C
#
# ---

# %% [markdown]
# ## Introduction
#
# *This section includes a short description of the data*

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import altair as alt
from pathlib import Path

# %% [markdown]
# ## Data

# %% [markdown]
# ## Import data

# %%
PARENT_PATH = str(Path().resolve().parent) + "/"
PATH = "data/"
SUBPATH = "external/"
FILE = "data"
FORMAT = ".csv"

PARENT_PATH


df = pd.read_csv(PARENT_PATH + PATH + SUBPATH + FILE + FORMAT)

# %% [markdown]
# ### Data structure

# %%
df
# Out:
#      year      brand                          superbowl_ads_dot_com_url  \
# 0    2018     Toyota        https://superbowl-ads.com/good-odds-toyota/
# 1    2020  Bud Light  https://superbowl-ads.com/2020-bud-light-seltz...
# 2    2006  Bud Light  https://superbowl-ads.com/2006-bud-light-bear-...
# 3    2018    Hynudai  https://superbowl-ads.com/hope-detector-nfl-su...
# 4    2003  Bud Light  https://superbowl-ads.com/2003-bud-light-hermi...
# ..    ...        ...                                                ...
# 239  2014        NFL                 https://superbowl-ads.com/nfl-now/
# 240  2012  Budweiser  https://superbowl-ads.com/2012-budweiser-etern...
# 241  2001      Pepsi  https://superbowl-ads.com/2001-pepsi-kasparov-...
# 242  2001    E-Trade  https://superbowl-ads.com/2001-etrade-security...
# 243  2001  Budweiser    https://superbowl-ads.com/2001-budweiser-nsync/
#
#                                      youtube_url  funny  show_product_quickly  \
# 0    https://www.youtube.com/watch?v=zeBZvwYQ-hA  False                 False
# 1    https://www.youtube.com/watch?v=nbbp0VW7z8w   True                  True
# 2    https://www.youtube.com/watch?v=yk0MQD5YgV8   True                 False
# 3    https://www.youtube.com/watch?v=lNPccrGk77A  False                  True
# 4    https://www.youtube.com/watch?v=ovQYgnXHooY   True                  True
# ..                                           ...    ...                   ...
# 239                                          NaN  False                  True
# 240  https://www.youtube.com/watch?v=_GeiOdHsW_8  False                  True
# 241  https://www.youtube.com/watch?v=pldGc0Cpf84   True                 False
# 242  https://www.youtube.com/watch?v=39BL7iqe6pQ   True                 False
# 243  https://www.youtube.com/watch?v=H9YdunAo3Ug  False                 False
#
#      patriotic  celebrity  danger  animals  use_sex
# 0        False      False   False    False    False
# 1        False       True    True    False    False
# 2        False      False    True     True    False
# 3        False      False   False    False    False
# 4        False      False    True     True     True
# ..         ...        ...     ...      ...      ...
# 239      False      False   False    False    False
# 240       True      False   False     True     True
# 241      False       True    True    False    False
# 242      False      False    True    False    False
# 243      False       True   False    False    False
#
# [244 rows x 11 columns]

# %%
df.dtypes
# Out:
# year                          int64
# brand                        object
# superbowl_ads_dot_com_url    object
# youtube_url                  object
# funny                          bool
# show_product_quickly           bool
# patriotic                      bool
# celebrity                      bool
# danger                         bool
# animals                        bool
# use_sex                        bool
# dtype: object

# %% [markdown]
# ### Data corrections

# %%
df = df.rename(columns={ 
            "superbowl_ads_dot_com_url": "url"
}, errors="raise")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [13], line 1
# ----> 1 df = df.rename(columns={
#       2             "superbowl_ads_dot_com_url": "url"
#       3 }, errors="raise")
#
# File ~/opt/anaconda3/envs/webscraping/lib/python3.9/site-packages/pandas/core/frame.py:5562, in DataFrame.rename(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    5443 def rename(
#    5444     self,
#    5445     mapper: Renamer | None = None,
#    (...)
#    5453     errors: IgnoreRaise = "ignore",
#    5454 ) -> DataFrame | None:
#    5455     """
#    5456     Alter axes labels.
#    5457
#    (...)
#    5560     4  3  6
#    5561     """
# -> 5562     return super()._rename(
#    5563         mapper=mapper,
#    5564         index=index,
#    5565         columns=columns,
#    5566         axis=axis,
#    5567         copy=copy,
#    5568         inplace=inplace,
#    5569         level=level,
#    5570         errors=errors,
#    5571     )
#
# File ~/opt/anaconda3/envs/webscraping/lib/python3.9/site-packages/pandas/core/generic.py:1102, in NDFrame._rename(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    1096     if errors == "raise" and len(indexer[indexer == -1]):
#    1097         missing_labels = [
#    1098             label
#    1099             for index, label in enumerate(replacements)
#    1100             if indexer[index] == -1
#    1101         ]
# -> 1102         raise KeyError(f"{missing_labels} not found in axis")
#    1104 new_index = ax._transform_index(f, level=level)
#    1105 result._set_axis_nocheck(new_index, axis=axis_no, inplace=True, copy=False)
#
# KeyError: "['superbowl_ads_dot_com_url'] not found in axis"

# %%
del df['youtube_url']

df
# Out:
#      year      brand                                                url  \
# 0    2018     Toyota        https://superbowl-ads.com/good-odds-toyota/
# 1    2020  Bud Light  https://superbowl-ads.com/2020-bud-light-seltz...
# 2    2006  Bud Light  https://superbowl-ads.com/2006-bud-light-bear-...
# 3    2018    Hynudai  https://superbowl-ads.com/hope-detector-nfl-su...
# 4    2003  Bud Light  https://superbowl-ads.com/2003-bud-light-hermi...
# ..    ...        ...                                                ...
# 239  2014        NFL                 https://superbowl-ads.com/nfl-now/
# 240  2012  Budweiser  https://superbowl-ads.com/2012-budweiser-etern...
# 241  2001      Pepsi  https://superbowl-ads.com/2001-pepsi-kasparov-...
# 242  2001    E-Trade  https://superbowl-ads.com/2001-etrade-security...
# 243  2001  Budweiser    https://superbowl-ads.com/2001-budweiser-nsync/
#
#      funny  show_product_quickly  patriotic  celebrity  danger  animals  \
# 0    False                 False      False      False   False    False
# 1     True                  True      False       True    True    False
# 2     True                 False      False      False    True     True
# 3    False                  True      False      False   False    False
# 4     True                  True      False      False    True     True
# ..     ...                   ...        ...        ...     ...      ...
# 239  False                  True      False      False   False    False
# 240  False                  True       True      False   False     True
# 241   True                 False      False       True    True    False
# 242   True                 False      False      False    True    False
# 243  False                 False      False       True   False    False
#
#      use_sex
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
# ..       ...
# 239    False
# 240     True
# 241    False
# 242    False
# 243    False
#
# [244 rows x 10 columns]

# %% [markdown]
# ## Exploratory data analysis
